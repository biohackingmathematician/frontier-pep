# %% [markdown]
# # 04 - TDA Exploration
#
# **Author:** Agna Chan | **Date:** December 2025
# **Repository:** [github.com/biohackingmathematician/frontier-pep](https://github.com/biohackingmathematician/frontier-pep)
#
# ---
#
# **CRITICAL DISCLAIMER**
#
# This notebook is for RESEARCH AND EDUCATIONAL PURPOSES ONLY.
# No medical advice, dosing, or protocol recommendations provided.

# %%
import sys
sys.path.insert(0, '../src')

import numpy as np
from peptide_atlas import print_disclaimer
from peptide_atlas.tda.filters import pca_filter, density_filter

print_disclaimer()

# Create sample embeddings for demonstration
np.random.seed(42)
embeddings = np.random.randn(30, 64)
print(f"Sample embeddings shape: {embeddings.shape}")
